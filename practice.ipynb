# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cityhousingprices = pd.read_csv('housingpricesbycity.csv')

# %%
cityhousingprices = cityhousingprices.iloc[[0,23, 14]]
cityhousingprices= cityhousingprices.drop("SizeRank", axis = 1)
cityhousingprices= cityhousingprices.drop("RegionType", axis = 1)
cityhousingprices= cityhousingprices.drop("RegionID", axis = 1)
cityhousingprices= cityhousingprices.drop("StateName", axis = 1)
cityhousingprices = cityhousingprices.T
cityhousingprices.columns = cityhousingprices.iloc[0]
cityhousingprices = cityhousingprices[1:]
cityhousingprices = cityhousingprices.reset_index()
cityhousingprices = cityhousingprices.rename(columns={"index": "Date"})
cityhousingprices.rename_axis(None, axis=1, inplace=True)

# %%
cityhousingprices['Date'] = pd.to_datetime(cityhousingprices['Date'])

# %%
cityhousingprices
# Out:
#           Date  United States  Charlotte, NC    Detroit, MI
# 0   2000-01-31  120187.291338  140499.671851  120704.608363
# 1   2000-02-29  120398.739312  140693.212243  120834.772831
# 2   2000-03-31  120660.965935  140948.661439  121160.751293
# 3   2000-04-30  121223.390567  141448.673507  121815.246193
# 4   2000-05-31  121870.673889  142024.856407  122676.059288
# ..         ...            ...            ...            ...
# 297 2024-10-31  354873.991396   377107.39206  245904.941589
# 298 2024-11-30   355358.91672  377215.469045  246575.155992
# 299 2024-12-31  356067.058847  377441.989904  247578.752934
# 300 2025-01-31  356686.351705  377793.731148  248730.482484
# 301 2025-02-28  357138.132256  377966.751635   249923.84005
#
# [302 rows x 4 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(cityhousingprices['Date'], cityhousingprices['United States'], color='b', linestyle='-', label='Price')


plt.xlabel('Date')
plt.ylabel('Average House Price ($)')
plt.title('Change in Average House Price Over Time in America')
plt.xticks(rotation=45) 
plt.grid(True)


plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(cityhousingprices['Date'], cityhousingprices['Charlotte, NC'], color='b', linestyle='-', label='Price')


plt.xlabel('Date')
plt.ylabel('Average House Price ($)')
plt.title('Change in Average House Price Over Time in Charlotte')
plt.xticks(rotation=45) 
plt.grid(True)


plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(cityhousingprices['Date'], cityhousingprices['Detroit, MI'], color='b', linestyle='-', label='Price')


plt.xlabel('Date')
plt.ylabel('Average House Price ($)')
plt.title('Change in Average House Price Over Time in Detroit')
plt.xticks(rotation=45) 
plt.grid(True)


plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(cityhousingprices['Date'], cityhousingprices['United States'], color='black', linestyle='-', label='US Average')
plt.plot(cityhousingprices['Date'], cityhousingprices['Charlotte, NC'], color='g', linestyle='-', label='Charlotte')
plt.plot(cityhousingprices['Date'], cityhousingprices['Detroit, MI'], color='r', linestyle='-', label='Detroit')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Change in Prices Over Time')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
